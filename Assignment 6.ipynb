# %% [markdown]
# Pick two datasets from the Github page.
# Pick two datasets from the web.
#
# Q1. Load your dataset into python using the pandas library and save data into a
# dataframe named dfi (where i is one of your datasets, for a total of 4).
# Q2. Preview your data by calling your dataframe’s name. How many columns and rows
# do you see?
# Q3. Examine the shape of your data using the .shape command and the data types of
# your columns using .dtypes.
# Q4. Use .describe() on your data. What do you notice about your data? What does this
# command return?
# Q5. Use the .head() and .tail() command - what does this do?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Dataset #1
# https://github.com/data602sps/datasetspractice/blob/main/kobe.csv

# %%
dfkobe = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv")
dfkobe
# Out:
#       vs  game quarter     time  \
# 0    ORL     1       1     9:47
# 1    ORL     1       1     9:07
# 2    ORL     1       1     8:11
# 3    ORL     1       1     7:41
# 4    ORL     1       1     7:03
# ..   ...   ...     ...      ...
# 128  ORL     3       4     3:33
# 129  ORL     3       4     2:02
# 130  ORL     3       4  00:23.9
# 131  ORL     3       4  00:06.9
# 132  ORL     3       4  00:00.5
#
#                                            description basket
# 0              Kobe Bryant makes 4-foot two point shot      H
# 1                            Kobe Bryant misses jumper      M
# 2                     Kobe Bryant misses 7-foot jumper      M
# 3    Kobe Bryant makes 16-foot jumper (Derek Fisher...      H
# 4                      Kobe Bryant makes driving layup      H
# ..                                                 ...    ...
# 128                        Bryant Layup Shot: Missed        M
# 129                          Bryant 3pt Shot: Missed        M
# ...

# %% [markdown]
# There are 133 rows and 6 columns.

# %%
dfkobe.shape
# Out:
# (133, 6)

# %%
dfkobe.dtypes
# Out:
# vs             object
# game            int64
# quarter        object
# time           object
# description    object
# basket         object
# dtype: object

# %%
dfkobe.describe()
# Out:
#              game
# count  133.000000
# mean     2.902256
# std      1.450521
# min      1.000000
# 25%      1.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000

# %% [markdown]
# It appears to give me summary statistics on my numerical column.

# %%
dfkobe.head()
# Out:
#     vs  game quarter  time                                        description  \
# 0  ORL     1       1  9:47            Kobe Bryant makes 4-foot two point shot
# 1  ORL     1       1  9:07                          Kobe Bryant misses jumper
# 2  ORL     1       1  8:11                   Kobe Bryant misses 7-foot jumper
# 3  ORL     1       1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...
# 4  ORL     1       1  7:03                    Kobe Bryant makes driving layup
#
#   basket
# 0      H
# 1      M
# 2      M
# 3      H
# 4      H

# %% [markdown]
# This shows the top few rows of the df.

# %%
dfkobe.tail()
# Out:
#       vs  game quarter     time                         description basket
# 128  ORL     3       4     3:33         Bryant Layup Shot: Missed        M
# 129  ORL     3       4     2:02           Bryant 3pt Shot: Missed        M
# 130  ORL     3       4  00:23.9           Bryant 3pt Shot: Missed        M
# 131  ORL     3       4  00:06.9           Bryant 3pt Shot: Missed        M
# 132  ORL     3       4  00:00.5  Bryant Layup Shot: Made (31 PTS)        H

# %% [markdown]
# This shows the bottom few rows of the df.

# %% [markdown]
# Dataset #2
# https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv

# %%
dfsalary = pd.read_csv("https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv")
dfsalary
# Out:
#                    Sate  2018 Mean Annual Wage  Unnamed: 2
# 0               Alabama                 90,620         NaN
# 1                 Alaska                99,180         NaN
# 2                Arizona                88,800         NaN
# 3               Arkansas                81,430         NaN
# 4             California                97,110         NaN
# 5               Colorado                82,560         NaN
# 6            Connecticut                96,010         NaN
# 7               Delaware                93,880         NaN
# 8   District of Columbia                89,880         NaN
# 9                Florida                87,410         NaN
# 10               Georgia                86,320         NaN
# 11                Hawaii                90,540         NaN
# 12                 Idaho                77,700         NaN
# 13              IIIinois                90,690         NaN
# 14               lndiana                83,680         NaN
# ...

# %%
dfsalary.shape
# Out:
# (51, 3)

# %% [markdown]
# There are 51 rows and 3 columns

# %%
dfsalary.dtypes
# Out:
# Sate                      object
# 2018 Mean Annual Wage     object
# Unnamed: 2               float64
# dtype: object

# %%
dfsalary.describe()
# Out:
#        Unnamed: 2
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %% [markdown]
# I believe that this is priotizing the column of NAs to tell me to handle them first. I believe that if they weren't there it would show me the summary stats.

# %%
dfsalary.head()
# Out:
#         Sate  2018 Mean Annual Wage  Unnamed: 2
# 0    Alabama                 90,620         NaN
# 1      Alaska                99,180         NaN
# 2     Arizona                88,800         NaN
# 3    Arkansas                81,430         NaN
# 4  California                97,110         NaN

# %%
dfsalary.tail()
# Out:
#             Sate  2018 Mean Annual Wage  Unnamed: 2
# 46       Virginia                91,700         NaN
# 47     Washington                85,930         NaN
# 48  West Virginia                89,420         NaN
# 49      Wisconsin                85,200         NaN
# 50        Wyomimg                87,510         NaN

# %% [markdown]
# Dataset #3
# https://www.kaggle.com/datasets/yasserh/wine-quality-dataset?select=WineQT.csv

# %%
dfwine = pd.read_csv("C:\\Users\\tyler\\Downloads\\DATA 602\\WineQT.csv")
dfwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
dfwine.shape
# Out:
# (1143, 13)

# %%
dfwine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
dfwine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
dfwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
dfwine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %% [markdown]
# Dataset #4
# https://www.kaggle.com/datasets/nickcory/iowa-state-university-enrollment-19982022

# %%
dfisu = pd.read_csv("C:\\Users\\tyler\\Downloads\\DATA 602\\ISU Enrollment.csv")
dfisu
# Out:
#     Year Semester  Ungrad  Prof  Grad  Post-Doc  Total
# 0   2022   Spring   24482   632  4122         0  29236
# 1   2021     Fall   25808   636  4264         0  30708
# 2   2021   Summer    6202   159  2713         0   9074
# 3   2021   Spring   24482   621  4265         0  29368
# 4   2020     Fall   26846   627  4352         0  31825
# ..   ...      ...     ...   ...   ...       ...    ...
# 66  2000   Spring   20251     0  4082         0  24333
# 67  1999     Fall   21901     0  4209         0  26110
# 68  1999   Summer    6033     0  2858         0   8891
# 69  1999   Spring   19825     0  4048         0  23873
# 70  1998     Fall   21427     0  4158         0  25585
#
# [71 rows x 7 columns]

# %%
dfisu.shape
# Out:
# (71, 7)

# %% [markdown]
# There are 71 rows and 7 columns.

# %%
dfisu.dtypes
# Out:
# Year         int64
# Semester    object
# Ungrad       int64
# Prof         int64
# Grad         int64
# Post-Doc     int64
# Total        int64
# dtype: object

# %%
dfisu.describe()
# Out:
#               Year        Ungrad        Prof         Grad    Post-Doc  \
# count    71.000000     71.000000   71.000000    71.000000   71.000000
# mean   2010.000000  18322.591549  337.323944  4081.478873   91.084507
# std       6.890988   8466.391096  242.918492   741.795868  141.837809
# min    1998.000000   5712.000000    0.000000  2713.000000    0.000000
# 25%    2004.000000   7725.500000  121.500000  3170.000000    0.000000
# 50%    2010.000000  21033.000000  408.000000  4364.000000    0.000000
# 75%    2016.000000  24482.000000  586.000000  4651.000000  289.500000
# max    2022.000000  30671.000000  636.000000  5096.000000  345.000000
#
#               Total
# count     71.000000
# mean   22832.478873
# std     9375.979161
# min     8891.000000
# 25%    11381.500000
# 50%    25863.000000
# 75%    29650.500000
# max    36660.000000

# %%
dfisu.head()
# Out:
#    Year Semester  Ungrad  Prof  Grad  Post-Doc  Total
# 0  2022   Spring   24482   632  4122         0  29236
# 1  2021     Fall   25808   636  4264         0  30708
# 2  2021   Summer    6202   159  2713         0   9074
# 3  2021   Spring   24482   621  4265         0  29368
# 4  2020     Fall   26846   627  4352         0  31825

# %%
dfisu.tail()
# Out:
#     Year Semester  Ungrad  Prof  Grad  Post-Doc  Total
# 66  2000   Spring   20251     0  4082         0  24333
# 67  1999     Fall   21901     0  4209         0  26110
# 68  1999   Summer    6033     0  2858         0   8891
# 69  1999   Spring   19825     0  4048         0  23873
# 70  1998     Fall   21427     0  4158         0  25585

# %% [markdown]
# Extra Credit Part 1
# 1. Choose one of your datasets and remove the header information. (Can delete
# the row in excel, etc..)
# 2. Import the data into your environment using pandas. Display the .head() of your
# data showing no header information.
# 3. Using pandas, update the dataset to include the header information. Display the
# updated data using .head().

# %%
df_new_kobe = pd.read_csv("https://raw.githubusercontent.com/tylerbaker01/datasetspractice/main/updatedkobe.csv")
df_new_kobe.head()
# Out:
#    ORL  1 1.1  9:47            Kobe Bryant makes 4-foot two point shot  H
# 0  ORL  1   1  9:07                          Kobe Bryant misses jumper  M
# 1  ORL  1   1  8:11                   Kobe Bryant misses 7-foot jumper  M
# 2  ORL  1   1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...  H
# 3  ORL  1   1  7:03                    Kobe Bryant makes driving layup  H
# 4  ORL  1   1  6:01                          Kobe Bryant misses jumper  M

# %%
colnames = ["opponent", "game", "quarter", "time", "description", "shot"]
df_kobe_updated = pd.read_csv("https://raw.githubusercontent.com/tylerbaker01/datasetspractice/main/updatedkobe.csv", names=colnames)
df_kobe_updated.head()
# Out:
#   opponent  game quarter  time  \
# 0      ORL     1       1  9:47
# 1      ORL     1       1  9:07
# 2      ORL     1       1  8:11
# 3      ORL     1       1  7:41
# 4      ORL     1       1  7:03
#
#                                          description shot
# 0            Kobe Bryant makes 4-foot two point shot    H
# 1                          Kobe Bryant misses jumper    M
# 2                   Kobe Bryant misses 7-foot jumper    M
# 3  Kobe Bryant makes 16-foot jumper (Derek Fisher...    H
# 4                    Kobe Bryant makes driving layup    H

# %% [markdown]
# Extra Credit Part 2
# 1. Import a “dirty” dataset from the internet into your environment. (Missing values,
# improper coding of columns, etc.)
# 2. Clean or “tidy” the data when loading into python using pandas.

# %%
vaccine_data = pd.read_csv("https://raw.githubusercontent.com/tylerbaker01/Data607-Assignment-5/main/israeli_vaccination_data_analysis_start.csv")
vaccine_data.head()
# Out:
#    Age Population %    Unnamed: 2              Severe Cases  \
# 0  NaN   Not Vax\n%  Fully Vax\n%  Not Vax\nper 100K\n\n\np
# 1  <50    1,116,834     3,501,118                        43
# 2             23.3%         73.0%                       NaN
# 3  >50      186,078     2,133,516                       171
# 4  NaN         7.9%         90.4%                       NaN
#
#             Unnamed: 4            Efficacy
# 0  Fully Vax\nper 100K  vs. severe disease
# 1                   11                 NaN
# 2                  NaN                 NaN
# 3                  290                 NaN
# 4                  NaN                 NaN
